# %% [markdown]
# # Merge Sort
# The second algorithm learned in the course is Merge sort, this is a bit tricky because it breaks the problem in two different functions and also becasue it uses recursion
#
#     - Divide: break the problem into smaller parts
#     - Conquer: combine results to solve larger problem
#
# The main thing to remember about merge sort is that from the list it will break apart into different lists, once reached to the bottom will join them again
#
# loop through left and right list, and keep looping until i or j == len of list, see which value at each location i and j is smaller and then join them to new list
# at the end if either list has more values to add, it will join add them to the list
#
# * IMPORTANT TO REMEMBER big O(nlogn) okay, cons, it takes a lot of memory becasue of the new list it creates

# %%
def merge_sort(my_list: list) -> list:
    '''Sorts a list using Merge Sort algorithm'''
    
    if  len(my_list) <= 1: return my_list # check base case where there are no more value in list then return the list
    left = merge_sort(my_list[:len(my_list) // 2]) #cut current list into a left half
    right = merge_sort(my_list[len(my_list) // 2:]) # slice current list into a right half
    return merge(listA=left, listB=right) #return value of merging sorted list

def merge(listA: list, listB: list)-> list:
    '''Merges both list, sorting them'''
    i, j = 0,0 #set values for i and j
    new_list = [] #new accumulator/ new list
    while i < len(listA) and j < len(listB): #loop until one of the variables has reached to the end of its list
        if listA[i] <= listB[j]: #if element at i is less than element at j then append value and increment i, plus edge case where both elements equal the same
            new_list.append(listA[i])
            i += 1
        elif listB[j] < listA[i]: #if element at j is less than element at i then append value and increment j
            new_list.append(listB[j])
            j += 1
        
        
    #if there are some left over values then add to the list 
    if i < len(listA): new_list.extend(listA[i:]) 
    elif j < len(listB): new_list.extend(listB[j:])
    return new_list #return new list

# %%
#testing merge_sort 
from random import randrange
array = [randrange(100) for i in range(100)]
print(merge_sort(array))
new_array = sorted(array)

assert merge_sort(array) == new_array
# Out:
# [2, 3, 4, 5, 7, 8, 9, 9, 9, 10, 10, 10, 11, 11, 12, 12, 14, 14, 17, 17, 19, 21, 21, 22, 22, 23, 23, 26, 26, 27, 29, 29, 29, 30, 30, 31, 32, 32, 32, 33, 34, 35, 36, 36, 37, 38, 38, 38, 38, 39, 39, 39, 40, 41, 42, 45, 47, 51, 54, 55, 56, 57, 58, 58, 58, 60, 60, 61, 61, 64, 69, 69, 69, 71, 72, 73, 76, 76, 76, 77, 77, 77, 81, 81, 81, 82, 82, 83, 84, 85, 87, 87, 88, 91, 92, 92, 93, 96, 96, 96]
